# %%
import glob
import os

os.chdir(r'C:\Users\USUARIO\Documents\Codigos\Proyecto e-commerce\Despiegue')

for numero in range(1, 9):
    coincidencias = glob.glob(f"{numero}. *.png") + glob.glob(f"{numero}.*.png")
    print(numero, "->", coincidencias)
# Out:
# 1 -> ['1. juguete.png', '1. juguete.png']
# 2 -> ['2. mueble.png', '2. mueble.png']
# 3 -> ['3. baño.png', '3. baño.png']
# 4 -> ['4. salud.png', '4. salud.png']
# 5 -> ['5. reloj.png', '5. reloj.png']
# 6 -> ['6. deporte.png', '6. deporte.png']
# 7 -> ['7. informatica.png', '7. informatica.png']
# 8 -> ['8. utilidades.png', '8. utilidades.png']
